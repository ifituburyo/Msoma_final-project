# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv("data.csv")
df.shape
print(f"columnxraws:{df.shape}")
df.info()
df.count()
df.head(5)
df.tail(3)
df.describe()
df.nunique()
df['Name in the language'].unique()
df['Countries'].unique()
df.isnull().sum()
df.duplicated().any()
fig,(ax1,ax2,ax3) = plt.subplots(3,1)
fig.suptitle("outlies")
sns.boxplot(df['Number of speakers'],ax=ax1,orient='v')
sns.boxplot(df['Longitude'],ax=ax2,orient='v')
sns.boxplot(df['Latitude'],ax=ax3,orient='v')
plt.figure(figsize = (15,5))
fig2 =sns.countplot(data=df,x="Degree of endangerment")

ea = df[df['Countries'].isin(['Kenya','Rwanda','Burundi'])]
ea.shape
ea.head()

plt.show()
angola =df[df['Countries'].isin(['Angola'])]
angola.shape

print(len(angola))
df['Country codes alpha 3'].replace('ANG','AZ',inplace =True)

df.info()
df.count()
# Out:
# columnxraws:(2722, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           2722 non-null   int64
#  1   Name in English              2722 non-null   object
#  2   Name in French               2699 non-null   object
#  3   Name in Spanish              2701 non-null   object
#  4   Countries                    2721 non-null   object
#  5   Country codes alpha 3        2721 non-null   object
#  6   ISO639-3 codes               2458 non-null   object
#  7   Degree of endangerment       2722 non-null   object
#  8   Alternate names              1583 non-null   object
#  9   Name in the language         27 non-null     object
#  10  Number of speakers           2539 non-null   float64
#  11  Sources                      2079 non-null   object
# ...
